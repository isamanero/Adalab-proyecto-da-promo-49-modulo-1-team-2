# %%
import random

# Función para mostrar las reglas
def mostrar_reglas():
    print("¡Bienvenido al juego de Piedra, Papel o Tijera!")
    print("Las reglas son simples:")
    print("Piedra gana a Tijera")
    print("Papel gana a Piedra")
    print("Tijera gana a Papel")

# Función para obtener la elección de la computadora
def obtener_eleccion_computadora():
    opciones = ['piedra', 'papel', 'tijera']
    return random.choice(opciones)

# Función para obtener la elección del jugador
def obtener_eleccion_jugador():
    opciones = ['piedra', 'papel', 'tijera']
    while True:
        jugador = input("Elige piedra, papel o tijera: ").lower()
        if jugador in opciones:
            return jugador
        else:
            print("Opción inválida. Por favor, elige entre piedra, papel o tijera.")

# Función para determinar el ganador
def determinar_ganador(jugador, computadora):
    if jugador == computadora:
        return "¡Es un empate!"
    elif (jugador == 'piedra' and computadora == 'tijera') or \
         (jugador == 'papel' and computadora == 'piedra') or \
         (jugador == 'tijera' and computadora == 'papel'):
        return "¡Ganaste!"
    else:
        return "¡Perdiste!"

# Función principal del juego
def jugar():
    mostrar_reglas()
    while True:
        jugador = obtener_eleccion_jugador()
        computadora = obtener_eleccion_computadora()
        print(f"La computadora eligió: {computadora}")
        
        resultado = determinar_ganador(jugador, computadora)
        print(resultado)
        
        jugar_otra_vez = input("¿Quieres jugar otra vez? (s/n): ").lower()
        if jugar_otra_vez != 's':
            print("Gracias por jugar. ¡Hasta luego!")
            break

# Llamar a la función principal para comenzar el juego
jugar()

# %%
import random

# Función para mostrar las reglas
def mostrar_reglas():
    print("¡Bienvenido al juego de Piedra, Papel o Tijera!")
    print("Las reglas son simples:")
    print("Piedra gana a Tijera")
    print("Papel gana a Piedra")
    print("Tijera gana a Papel")
    print("El primero que llegue a 3 puntos gana.")

# Función para obtener la elección de la computadora
def obtener_eleccion_computadora():
    opciones = ['piedra', 'papel', 'tijera']
    return random.choice(opciones)

# Función para obtener la elección del jugador
def obtener_eleccion_jugador():
    opciones = ['piedra', 'papel', 'tijera']
    while True:
        jugador = input("Elige piedra, papel o tijera: ").lower()
        if jugador in opciones:
            return jugador
        else:
            print("Opción inválida. Por favor, elige entre piedra, papel o tijera.")

# Función para determinar el ganador
def determinar_ganador(jugador, computadora):
    if jugador == computadora:
        return "empate"
    elif (jugador == 'piedra' and computadora == 'tijera') or \
         (jugador == 'papel' and computadora == 'piedra') or \
         (jugador == 'tijera' and computadora == 'papel'):
        return "jugador"
    else:
        return "computadora"

# Función principal del juego
def jugar():
    mostrar_reglas()
    
    puntos_jugador = 0
    puntos_computadora = 0

    while puntos_jugador < 3 and puntos_computadora < 3:
        jugador = obtener_eleccion_jugador()
        computadora = obtener_eleccion_computadora()
        print(f"La computadora eligió: {computadora}")
        
        resultado = determinar_ganador(jugador, computadora)
        
        if resultado == "empate":
            print("¡Es un empate! Ninguno gana un punto.")
        elif resultado == "jugador":
            puntos_jugador += 1
            print("¡Ganaste esta ronda! Has ganado un punto.")
        else:
            puntos_computadora += 1
            print("¡La computadora ganó esta ronda! La computadora ha ganado un punto.")
        
        # Mostrar puntuaciones
        print(f"Puntuación actual - Jugador: {puntos_jugador} | Computadora: {puntos_computadora}")
        print("-----------------------------------------------------------")

    # Declarar el ganador
    if puntos_jugador == 3:
        print("¡Felicidades! Has ganado el juego.")
    else:
        print("¡La computadora ha ganado el juego!")

# Llamar a la función principal para comenzar el juego
jugar()
# Out:
# ¡Bienvenido al juego de Piedra, Papel o Tijera!
# Las reglas son simples:
# Piedra gana a Tijera
# Papel gana a Piedra
# Tijera gana a Papel
# El primero que llegue a 3 puntos gana.
# La computadora eligió: tijera
# ¡Es un empate! Ninguno gana un punto.
# Puntuación actual - Jugador: 0 | Computadora: 0
# -----------------------------------------------------------
# La computadora eligió: piedra
# ¡Es un empate! Ninguno gana un punto.
# Puntuación actual - Jugador: 0 | Computadora: 0
# -----------------------------------------------------------
# La computadora eligió: papel
# ¡Es un empate! Ninguno gana un punto.
# Puntuación actual - Jugador: 0 | Computadora: 0
# -----------------------------------------------------------
# La computadora eligió: piedra
# ¡Ganaste esta ronda! Has ganado un punto.
# Puntuación actual - Jugador: 1 | Computadora: 0
# -----------------------------------------------------------
# La computadora eligió: piedra
# ¡Ganaste esta ronda! Has ganado un punto.
# ...

# %%
import random

def obtener_eleccion_usuario():
    opciones = ["piedra", "papel", "tijera"]
    while True:
        eleccion = input("Elige piedra, papel o tijera: ").lower()
        if eleccion in opciones:
            return eleccion
        else:
            print("Entrada no válida. Intenta de nuevo.")

def obtener_eleccion_computadora():
    return random.choice(["piedra", "papel", "tijera"])

def determinar_ganador(jugador, computadora):
    if jugador == computadora:
        return "Empate"
    elif (jugador == "piedra" and computadora == "tijera") or \
         (jugador == "tijera" and computadora == "papel") or \
         (jugador == "papel" and computadora == "piedra"):
        return "Jugador"
    else:
        return "Computadora"

def jugar():
    rondas_total =5
    puntaje_jugador = 0
    puntaje_computadora = 0
    puntos_objetivo=3
    rondas_jugadas=0
    while puntaje_jugador < puntos_objetivo and puntaje_computadora < puntos_objetivo and  rondas_jugadas<rondas_total:
        jugador = obtener_eleccion_usuario()
        computadora = obtener_eleccion_computadora()
        print(f"Computadora eligió: {computadora}")
        print(f"jugador eligió: {jugador}") 
        

        ganador = determinar_ganador(jugador, computadora)
        if ganador == "Jugador":
            puntaje_jugador += 1
            print("¡Ganaste esta ronda!")
        elif ganador == "Computadora":
            puntaje_computadora += 1
            print("La computadora gana esta ronda.")
        else:
            print("Es un empate.")

        print(f"Puntuación -> Jugador: {puntaje_jugador} | Computadora: {puntaje_computadora}\n")

         


        
    if puntaje_jugador > puntaje_computadora:
        print("🎉 ¡Felicidades! Ganaste el juego.")
    elif puntaje_jugador < puntaje_computadora:
        print("😢 La computadora ganó el juego.")
    else:
        print("🤝 Es un empate en el juego.")



   
# Iniciar el juego
jugar()
# Out:
# Computadora eligió: piedra
# jugador eligió: piedra
# Es un empate.
# Puntuación -> Jugador: 0 | Computadora: 0
#
# Computadora eligió: papel
# jugador eligió: papel
# Es un empate.
# Puntuación -> Jugador: 0 | Computadora: 0
#
# Computadora eligió: papel
# jugador eligió: tijera
# ¡Ganaste esta ronda!
# Puntuación -> Jugador: 1 | Computadora: 0
#
# Computadora eligió: tijera
# jugador eligió: papel
# La computadora gana esta ronda.
# Puntuación -> Jugador: 1 | Computadora: 1
#
# Computadora eligió: papel
# jugador eligió: papel
# Es un empate.
# Puntuación -> Jugador: 1 | Computadora: 1
#
# Entrada no válida. Intenta de nuevo.
# Computadora eligió: papel
# jugador eligió: tijera
# ¡Ganaste esta ronda!
# Puntuación -> Jugador: 2 | Computadora: 1
#
# Computadora eligió: papel
# jugador eligió: piedra
# La computadora gana esta ronda.
# Puntuación -> Jugador: 2 | Computadora: 2
#
# Computadora eligió: papel
# jugador eligió: tijera
# ¡Ganaste esta ronda!
# ...

# %%
import random

def obtener_eleccion_usuario():
    opciones = ["piedra", "papel", "tijera"]
    while True:
        eleccion = input("Elige piedra, papel o tijera: ").lower()
        if eleccion in opciones:
            return eleccion
        else:
            print("Entrada no válida. Intenta de nuevo.")

def obtener_eleccion_computadora():
    return random.choice(["piedra", "papel", "tijera"])

def determinar_ganador(jugador, computadora):
    if jugador == computadora:
        return "Empate"
    elif (jugador == "piedra" and computadora == "tijera") or \
         (jugador == "tijera" and computadora == "papel") or \
         (jugador == "papel" and computadora == "piedra"):
        return "Jugador"
    else:
        return "Computadora"

def jugar():
    rondas_maximas = 5  
    puntos_objetivo = 3  
    puntaje_jugador = 0
    puntaje_computadora = 0
    ronda_actual = 0  

    while ronda_actual < rondas_maximas and puntaje_jugador < puntos_objetivo and puntaje_computadora < puntos_objetivo:
        ronda_actual += 1
        print(f"\n🔹 Ronda {ronda_actual} de {rondas_maximas}")

        jugador = obtener_eleccion_usuario()
        computadora = obtener_eleccion_computadora()
        
        print(f"\nComputadora eligió: {computadora}")
        print(f"Jugador eligió: {jugador}") 

        ganador = determinar_ganador(jugador, computadora)
        if ganador == "Jugador":
            puntaje_jugador += 1
            print("¡Ganaste esta ronda! 🎉")
        elif ganador == "Computadora":
            puntaje_computadora += 1
            print("La computadora gana esta ronda. 🤖")
        else:
            print("Es un empate. 🤝")

        print(f"Puntuación -> Jugador: {puntaje_jugador} | Computadora: {puntaje_computadora}")

    # Determinar el ganador final
    print("\n🎯 RESULTADO FINAL 🎯")
    if puntaje_jugador > puntaje_computadora:
        print("🎉 ¡Felicidades! Ganaste el juego.")
    elif puntaje_jugador < puntaje_computadora:
        print("😢 La computadora ganó el juego.")
    else:
        print("🤝 El juego terminó en empate.")

# Iniciar el juego
jugar()
# Out:
# 🔹 Ronda 1 de 5
# Entrada no válida. Intenta de nuevo.
#
# Computadora eligió: tijera
# Jugador eligió: piedra
# ¡Ganaste esta ronda! 🎉
# Puntuación -> Jugador: 1 | Computadora: 0
#
# 🔹 Ronda 2 de 5
#
# Computadora eligió: tijera
# Jugador eligió: papel
# La computadora gana esta ronda. 🤖
# Puntuación -> Jugador: 1 | Computadora: 1
#
# 🔹 Ronda 3 de 5
#
# Computadora eligió: tijera
# Jugador eligió: tijera
# Es un empate. 🤝
# Puntuación -> Jugador: 1 | Computadora: 1
#
# 🔹 Ronda 4 de 5
#
# Computadora eligió: papel
# Jugador eligió: papel
# Es un empate. 🤝
# Puntuación -> Jugador: 1 | Computadora: 1
#
# 🔹 Ronda 5 de 5
#
# Computadora eligió: papel
# Jugador eligió: piedra
# La computadora gana esta ronda. 🤖
# Puntuación -> Jugador: 1 | Computadora: 2
#
# 🎯 RESULTADO FINAL 🎯
# 😢 La computadora ganó el juego.
