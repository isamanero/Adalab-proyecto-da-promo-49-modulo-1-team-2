# %%
import random

def obtener_eleccion_usuario():
    opciones = ["piedra", "papel", "tijera"]
    while True:
        eleccion = input("Elige piedra, papel o tijera: ").lower()
        if eleccion in opciones:
            return eleccion
        else:
            print("Entrada no válida. Intenta de nuevo.")

def obtener_eleccion_computadora():
    return random.choice(["piedra", "papel", "tijera"])

def determinar_ganador(jugador, computadora):
    if jugador == computadora:
        return "Empate"
    elif (jugador == "piedra" and computadora == "tijera") or \
         (jugador == "tijera" and computadora == "papel") or \
         (jugador == "papel" and computadora == "piedra"):
        return "Jugador"
    else:
        return "Computadora"

def jugar():
    rondas = 3   
    puntaje_jugador = 0
    puntaje_computadora = 0

    for _ in range(rondas):
        jugador = obtener_eleccion_usuario()
        computadora = obtener_eleccion_computadora()
        print(f"Computadora eligió: {computadora}")
        print(f"jugador eligió: {jugador}") 

        ganador = determinar_ganador(jugador, computadora)
        if ganador == "Jugador":
            puntaje_jugador += 1
            print("¡Ganaste esta ronda!")
        elif ganador == "Computadora":
            puntaje_computadora += 1
            print("La computadora gana esta ronda.")
        else:
            print("Es un empate.")

        print(f"Puntuación -> Jugador: {puntaje_jugador} | Computadora: {puntaje_computadora}\n")

    if puntaje_jugador > puntaje_computadora:
        print("🎉 ¡Felicidades! Ganaste el juego.")
    elif puntaje_jugador < puntaje_computadora:
        print("😢 La computadora ganó el juego.")
    else:
        print("🤝 Es un empate en el juego.")

# Iniciar el juego
jugar()
# Out:
# Computadora eligió: piedra
# jugador eligió: tijera
# La computadora gana esta ronda.
# Puntuación -> Jugador: 0 | Computadora: 1
#
# Computadora eligió: piedra
# jugador eligió: papel
# ¡Ganaste esta ronda!
# Puntuación -> Jugador: 1 | Computadora: 1
#
# Computadora eligió: piedra
# jugador eligió: piedra
# Es un empate.
# Puntuación -> Jugador: 1 | Computadora: 1
#
# 🤝 Es un empate en el juego.

# %%
import random

def obtener_eleccion_usuario():
    opciones = ["piedra", "papel", "tijera"]
    while True:
        eleccion = input("Elige piedra, papel o tijera: ").lower()
        if eleccion in opciones:
            return eleccion
        else:
            print("Entrada no válida. Intenta de nuevo.")

def obtener_eleccion_computadora():
    return random.choice(["piedra", "papel", "tijera"])

def determinar_ganador(jugador, computadora):
    if jugador == computadora:
        return "Empate"
    elif (jugador == "piedra" and computadora == "tijera") or \
         (jugador == "tijera" and computadora == "papel") or \
         (jugador == "papel" and computadora == "piedra"):
        return "Jugador"
    else:
        return "Computadora"


def jugar():
    puntos_objetivo = 3  # Se necesitan 3 puntos para ganar
    puntaje_jugador = 0
    puntaje_computadora = 0

    
    while puntaje_jugador < puntos_objetivo and puntaje_computadora < puntos_objetivo:
        jugador = obtener_eleccion_usuario()
        computadora = obtener_eleccion_computadora()
        print(f"Computadora eligió: {computadora}")
        print(f"jugador eligió: {jugador}") 

        ganador = determinar_ganador(jugador, computadora)
        if ganador == "Jugador":
            puntaje_jugador += 1
            print("¡Ganaste esta ronda!")
        elif ganador == "Computadora":
            puntaje_computadora += 1
            print("La computadora gana esta ronda.")
        else:
            print("Es un empate.")

        print(f"Puntuación -> Jugador: {puntaje_jugador} | Computadora: {puntaje_computadora}\n")
        

    if puntaje_jugador > puntaje_computadora:
        print("🎉 ¡Felicidades! Ganaste el juego.")
    elif puntaje_jugador < puntaje_computadora:
        print("😢 La computadora ganó el juego.")
    else:
        print("🤝 Es un empate en el juego.")

# Iniciar el juego
jugar()
# Out:
# Computadora eligió: tijera
# jugador eligió: piedra
# ¡Ganaste esta ronda!
# Puntuación -> Jugador: 1 | Computadora: 0
#
# Computadora eligió: piedra
# jugador eligió: tijera
# La computadora gana esta ronda.
# Puntuación -> Jugador: 1 | Computadora: 1
#
# Computadora eligió: piedra
# jugador eligió: papel
# ¡Ganaste esta ronda!
# Puntuación -> Jugador: 2 | Computadora: 1
#
# Computadora eligió: piedra
# jugador eligió: piedra
# Es un empate.
# Puntuación -> Jugador: 2 | Computadora: 1
#
# Computadora eligió: piedra
# jugador eligió: tijera
# La computadora gana esta ronda.
# Puntuación -> Jugador: 2 | Computadora: 2
#
# Computadora eligió: papel
# jugador eligió: papel
# Es un empate.
# Puntuación -> Jugador: 2 | Computadora: 2
#
# Computadora eligió: tijera
# jugador eligió: tijera
# Es un empate.
# Puntuación -> Jugador: 2 | Computadora: 2
#
# Computadora eligió: piedra
# jugador eligió: piedra
# Es un empate.
# Puntuación -> Jugador: 2 | Computadora: 2
#
# Computadora eligió: tijera
# jugador eligió: papel
# La computadora gana esta ronda.
# Puntuación -> Jugador: 2 | Computadora: 3
#
# 😢 La computadora ganó el juego.

# %%
jugador = 0
maquina = 0
while True :
    opcion_jugador = input("cual es tu opción: ")

    opcion_maquina = "tijera"

    if opcion_jugador == "piedra":
        jugador +=1
    else : 
        maquina += 1

    if jugador == 3:
        print ("gana jugador")
        break 
    if maquina == 3:
        print ("gana la maquina")
        break
# Out:
# gana jugador

# %% [markdown]
# # Ultima versión

# %%
import random

def obtener_eleccion_usuario():
    opciones = ["piedra", "papel", "tijera"]
    while True:
        eleccion = input("Elige piedra, papel o tijera: ").lower()
        if eleccion in opciones:
            return eleccion
        else:
            print("Entrada no válida. Intenta de nuevo.")

def obtener_eleccion_computadora():
    return random.choice(["piedra", "papel", "tijera"])

def determinar_ganador(jugador, computadora):
    if jugador == computadora:
        return "Empate"
    elif (jugador == "piedra" and computadora == "tijera") or \
         (jugador == "tijera" and computadora == "papel") or \
         (jugador == "papel" and computadora == "piedra"):
        return "Jugador"
    else:
        return "Computadora"

def jugar():
    puntos_objetivo = 3  # Se necesitan 3 puntos para ganar
    max_rondas = 10  # Máximo de 10 rondas
    puntaje_jugador = 0
    puntaje_computadora = 0
    rondas_jugadas = 0

    while puntaje_jugador < puntos_objetivo and puntaje_computadora < puntos_objetivo and rondas_jugadas < max_rondas:
        jugador = obtener_eleccion_usuario()
        computadora = obtener_eleccion_computadora()
        print(f"Computadora eligió: {computadora}")
        print(f"Jugador eligió: {jugador}")

        ganador = determinar_ganador(jugador, computadora)
        if ganador == "Jugador":
            puntaje_jugador += 1
            print("¡Ganaste esta ronda!")
        elif ganador == "Computadora":
            puntaje_computadora += 1
            print("La computadora gana esta ronda.")
        else:
            print("Es un empate.")

        rondas_jugadas += 1
        print(f"Puntuación -> Jugador: {puntaje_jugador} | Computadora: {puntaje_computadora}")
        print(f"Rondas jugadas: {rondas_jugadas}/{max_rondas}\n")

    # Determinar el resultado final
    if puntaje_jugador > puntaje_computadora:
        print("🎉 ¡Felicidades! Ganaste el juego.")
    elif puntaje_jugador < puntaje_computadora:
        print("😢 La computadora ganó el juego.")
    else:
        print("🤝 Es un empate en el juego.")

# Iniciar el juego
jugar()
# Out:
# Computadora eligió: tijera
# Jugador eligió: piedra
# ¡Ganaste esta ronda!
# Puntuación -> Jugador: 1 | Computadora: 0
# Rondas jugadas: 1/10
#
# Computadora eligió: tijera
# Jugador eligió: papel
# La computadora gana esta ronda.
# Puntuación -> Jugador: 1 | Computadora: 1
# Rondas jugadas: 2/10
#
# Computadora eligió: piedra
# Jugador eligió: tijera
# La computadora gana esta ronda.
# Puntuación -> Jugador: 1 | Computadora: 2
# Rondas jugadas: 3/10
#
# Computadora eligió: tijera
# Jugador eligió: tijera
# Es un empate.
# Puntuación -> Jugador: 1 | Computadora: 2
# Rondas jugadas: 4/10
#
# Computadora eligió: papel
# Jugador eligió: piedra
# La computadora gana esta ronda.
# Puntuación -> Jugador: 1 | Computadora: 3
# Rondas jugadas: 5/10
#
# 😢 La computadora ganó el juego.
